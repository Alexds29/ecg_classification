# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import Pipes.grid_search_cv as gs
#import Pipes.train_test_split_2 as tts

# %% [markdown]
# ## Загрузка моделей

# %%
#mod_name = 'random_forest.pkl'
#with open(mod_name , 'rb') as f:
#    forest = pickle.load(f)

# %%
#mod_name = 'gradient_boosting.pkl'
#with open(mod_name , 'rb') as f:
#   grad = pickle.load(f)

# %%
#mod_name = 'svc.pkl'
#with open(mod_name , 'rb') as f:
#    svc = pickle.load(f)

# %% [markdown]
# ## Отбор лучших моделей

# %%
## Модели и их параметры для отбора
forest = RandomForestClassifier()
forest_params = {'n_estimators': range(10, 101, 10), 'criterion': ['gini', 'entropy', 'log_loss'], 'max_depth': range(3, 16, 2)}

#svc = SVC()
#svc_params = {'kernel': ['rbf'], 'C': [0.01, 0.1, 0.5, 1]}

grad = GradientBoostingClassifier()
grad_params = {'learning_rate': [0.001, 0.01, 0.1], 'n_estimators' : [10, 40, 70, 100]}

# %%
#Отбираем лучшую модель random_forest
gs.grid_search(forest, forest_params)
# Out:
# Fitting 5 folds for each of 210 candidates, totalling 1050 fits
# C:\Users\Alex_DS\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:598: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Alex_DS\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:598: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Alex_DS\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:598: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
#Отбираем лучшую модель svc
#gs.grid_search(svc, svc_params)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Users\Alex_DS\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Alex_DS\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Alex_DS\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
#Отбираем лучшую модель GradientBoosting
gs.grid_search(grad, grad_params)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\Alex_DS\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Alex_DS\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Alex_DS\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
# Среди отобранных моделей наилучшим образом обобщает данные модель GradientBoosting
# так как показатель точности у нее самый высокий - 0.852
