# %%
import pandas as pd
import Pipes.pipe_processing as pp

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Чтение и осмотр данных

# %%
df = pd.read_csv('Diagnostics.csv')

# %%
df
# Out:
#                          FileName Rhythm       Beat  PatientAge  Gender  \
# 0      MUSE_20180113_171327_27000   AFIB   RBBB TWC          85    MALE
# 1      MUSE_20180112_073319_29000     SB        TWC          59  FEMALE
# 2      MUSE_20180111_165520_97000     SA       NONE          20  FEMALE
# 3      MUSE_20180113_121940_44000     SB       NONE          66    MALE
# 4      MUSE_20180112_122850_57000     AF  STDD STTC          73  FEMALE
# ...                           ...    ...        ...         ...     ...
# 10641  MUSE_20181222_204306_99000    SVT       NONE          80  FEMALE
# 10642  MUSE_20181222_204309_22000    SVT       NONE          81  FEMALE
# 10643  MUSE_20181222_204310_31000    SVT       NONE          39    MALE
# 10644  MUSE_20181222_204312_58000    SVT       NONE          76    MALE
# 10645  MUSE_20181222_204314_78000    SVT       NONE          75    MALE
#
#        VentricularRate  AtrialRate  QRSDuration  QTInterval  QTCorrected  \
# ...

# %%
#Список всех признаков
df.columns
# Out:
# Index(['FileName', 'Rhythm', 'Beat', 'PatientAge', 'Gender', 'VentricularRate',
#        'AtrialRate', 'QRSDuration', 'QTInterval', 'QTCorrected', 'RAxis',
#        'TAxis', 'QRSCount', 'QOnset', 'QOffset', 'TOffset'],
#       dtype='object')

# %%
#Пустых значений нет
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10646 entries, 0 to 10645
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FileName         10646 non-null  object
#  1   Rhythm           10646 non-null  object
#  2   Beat             10646 non-null  object
#  3   PatientAge       10646 non-null  int64
#  4   Gender           10646 non-null  object
#  5   VentricularRate  10646 non-null  int64
#  6   AtrialRate       10646 non-null  int64
#  7   QRSDuration      10646 non-null  int64
#  8   QTInterval       10646 non-null  int64
#  9   QTCorrected      10646 non-null  int64
#  10  RAxis            10646 non-null  int64
#  11  TAxis            10646 non-null  int64
#  12  QRSCount         10646 non-null  int64
#  13  QOnset           10646 non-null  int64
#  14  QOffset          10646 non-null  int64
#  15  TOffset          10646 non-null  int64
# dtypes: int64(12), object(4)
# ...

# %%
#Статистические данные по числовым признакам
df.describe()
# Out:
#          PatientAge  VentricularRate   AtrialRate   QRSDuration    QTInterval  \
# count  10646.000000     10646.000000  10646.00000  10646.000000  10646.000000
# mean      59.186831        84.136107     92.57787     90.989292    384.150855
# std       18.030019        34.455349     60.09394     17.479540     59.226289
# min        4.000000        34.000000      0.00000     18.000000    114.000000
# 25%       49.000000        57.000000     57.00000     80.000000    344.000000
# 50%       62.000000        73.000000     72.00000     88.000000    390.000000
# 75%       72.000000       104.000000    106.00000     98.000000    426.000000
# max       98.000000       263.000000    535.00000    256.000000    736.000000
#
#         QTCorrected         RAxis         TAxis      QRSCount        QOnset  \
# count  10646.000000  10646.000000  10646.000000  10646.000000  10646.000000
# mean     434.154048     39.620609     44.637704     13.839470    219.260567
# ...

# %%
#Количество экземпляров каждого класса по целевой переменной
df['Rhythm'].value_counts()
# Out:
# SB       3889
# SR       1826
# AFIB     1780
# ST       1568
# SVT       587
# AF        445
# SA        399
# AT        121
# AVNRT      16
# AVRT        8
# SAAWR       7
# Name: Rhythm, dtype: int64

# %% [markdown]
# ### Обработка данных

# %%
df = pp.myPipe.transform(df)

# %%
df
# Out:
#        Rhythm  PatientAge  Gender  VentricularRate  AtrialRate  QRSDuration  \
# 0           2          85       1              117         234          114
# 1           0          59       0               52          52           92
# 2           6          20       0               67          67           82
# 3           0          66       1               53          53           96
# 4           5          73       0              162         162          114
# ...       ...         ...     ...              ...         ...          ...
# 10641       4          80       0              196          73          168
# 10642       4          81       0              162          81          162
# 10643       4          39       1              152          92          152
# 10644       4          76       1              175         178          128
# 10645       4          75       1              117         104          140
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Сохраняем датафрейм

# %%
df.to_csv('Diagnostics_processing.csv')

# %% [markdown]
# ### Выделение метки, разделение множества на тестовое и обучающее

# %%
X = df.drop(['Rhythm'], axis = 1)
Y = df['Rhythm']

# %%
X.to_csv('X.csv')
Y.to_csv('Y.csv')

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42, stratify = Y)
